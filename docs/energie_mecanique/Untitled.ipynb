# %% [markdown]
# Energie mécanique d’un système
# Fiche élèves
#
#
#
# Lustre suspendu à la voûte de la cathédrale de Pise (image wikipédia)
# Document 1
# GALILÉE (1564-1642) est, semble-t-il, le premier à avoir étudié de manière quantitative les oscillations en observant le balancement d'un lustre suspendu à la voûte de la cathédrale de Pise. Il découvre ainsi les lois du mouvement pendulaire, à la base des premières horloges à pendule.
#
# Un pendule simple est constitué d'un solide de masse m, de petite dimension, suspendu à un fil inextensible, de masse négligeable devant m et de longueur très supérieure aux dimensions du solide. On note   la longueur du pendule (distance entre le point d'attache et le centre de gravité du solide). La position du pendule sera repérée par ses coordonnées (x,y) dans un repère  .
#
#
# Document 2 : Mesures
#  	La masse du pendule est 186,64 g.
#  	Le montage utilisé est le suivant (pendule pesant relié à une carte arduino):
#
#
#
# Document 3 : Energie d’un système
# 1.	Energie cinétique :
# L’énergie cinétique d’un objet de masse m (en kg) en mouvement à la vitesse v (en m.s-1) dans un référentiel (R) est donnée par la relation :
#
# 2.	Energie potentielle de pesanteur et énergie mécanique :
# On considère un système de masse m (en kg) assimilé à un point matériel d’énergie cinétique Ec (en J) et dont l’altitude z (en m) est repérée par un axe vertical ascendant Oz (en m).
# L’énergie potentielle de pesanteur (en J) de ce système est donnée par la relation :
#
#
# Son énergie mécanique (en J) est donnée par la relation :
#
# Donnée :
#
#
#
#
#
#
# # Travail à effectuer
#
# Une feuille de compte rendu est indispensable
#
# ## 1. Dispositif
# - Ordinateur muni du logiciel Arduino et environnement python
# - Pendule pesant de masse 186,64 g.
#
# ## 2. Mesures
# a. Ouvrir le fichier pendule.ino dans le logiciel Arduino.
# b. Sélectionner le port COM et téléverser le programme dans la carte.
# c. Exécuter le programme python mesures_pendule.py.
# d. Lancer le pendule, taper mesures dans la boite de dialogue (puis entrée).
# e. Si les mesures vous conviennent, fermer la fenêtre graphique et taper sauve dans la boite de dialogue. Un fichier mesures_pendule.csv est enregistré. Il contient le tableau des valeurs de t, x, y.
#
# ## 3. Exploitation
# On utilisera le fichier « energie_pendule.py »
# a.	Renseignez la masse du pendule :
# m = ...
# b.	Calculez les valeurs de l'énergie potentielle de pesanteur   pour chaque pointage :
# ### calcul des énergies potentielles de pesanteur
# Epp = []
#
# for i in range(1,len(t)-1):
#     Epp_i = ...
#     Epp.append(Epp_i)
# c.	Calculez les coordonnées   et   du vecteur vitesse pour chaque position du pendule :
# ### calcul des Ec
# Ec = []
# for i in range(1,len(t)-1):
#     vx = ( ... )
#     vy = ( ... )
# d.	En déduire la valeur de la vitesse aux différentes dates.
#     v = ...
# e. 	Calculez les valeurs de l'énergie cinétique   pour chaque pointage.
#     Ec_i = ...
#     Ec.append(Ec_i)
# f.	Déterminez à chaque instant la valeur de l’énergie mécanique   du pendule.
# # énergies mécaniques
# E = []
# for i in range(len(t1)):
#     E_i = ...
#     E.append(E_i)
#
# 4.	Questions
# a.	Relevez la valeur maximale de l'énergie potentielle de pesanteur. À quelle position du pendule correspond-elle?
# b.	Comment évolue l'énergie potentielle de pesanteur du solide au cours d'une période d'oscillation?
# c.	Relevez la valeur maximale de l'énergie cinétique. À quelle position du pendule correspond-elle?
# e.	Comment évolue l'énergie cinétique au cours d'une période d'oscillation?
# f.	Indiquez comment évolue l'énergie mécanique du pendule. Conclure.
